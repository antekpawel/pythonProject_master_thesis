# %% [markdown]
# # Introduction
#
# ### Heart Disease data set:
#
# This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them. In particular, the Cleveland database is the only one that has been used by ML researchers to
# this date. The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4.
#
# Source: https://archive.ics.uci.edu/ml/datasets/Heart+Disease

# %% [markdown]
# ### Attribute Information:
#
# #####        1. age
# #####         2. sex
# #####         3. chest pain type (4 values)
# #####         4. resting blood pressure
# #####         5. serum cholestoral in mg/dl
# #####         6. fasting blood sugar > 120 mg/dl
# #####         7. resting electrocardiographic results (values 0,1,2)
# #####         8. maximum heart rate achieved
# #####         9. exercise induced angina
# #####         10. oldpeak = ST depression induced by exercise relative to rest
# #####         11. the slope of the peak exercise ST segment
# #####         12. number of major vessels (0-3) colored by flourosopy
# #####         13. thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# ### Acknowledgements:
#
# #### Creators:
#
# ###### 1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
# ######    2 .University Hospital, Zurich, Switzerland: William Steinbrunn, M.D.
# ######    3. University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D.
# ######    4. V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.

# %% [markdown]
# ### Import libraries and data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext lab_black

# %%
# read raw data
raw_data = pd.read_csv("Data/heart.csv")

# %%
# show first 5 rows
raw_data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# show shape of data
raw_data.shape
# Out:
# (303, 14)

# %% [markdown]
# ## Data cleaning

# %%
# check is there missing data
raw_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# check is there duplicated rows
raw_data.duplicated(subset=None, keep="first").sum()
# Out:
# 1

# %%
# let's select duplicate row
duplicatedrow = raw_data[raw_data.duplicated(keep="last")]
duplicatedrow
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 163   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 163      2   4     2       1

# %%
# drop duplicate row
raw_data = raw_data.drop_duplicates()

# %%
# show shape of data
raw_data.shape
# Out:
# (302, 14)

# %% [markdown]
# #### This data set is too small, so splitting to validation data may give unrepresentative data.

# %% [markdown]
# ## Look inside data

# %%
# rename column from target to heart disease and values 0 to No and 1 to Yes in this column
raw_data = raw_data.rename(columns={"target": "heart_disease"})
raw_data["heart_disease"].replace({0: "No", 1: "Yes"}, inplace=True)
change = ["cp", "restecg", "slope", "ca", "thal"]
for c, value in enumerate(change, 1):
    raw_data[value].replace(
        {0: "zero", 1: "one", 2: "two", 3: "three", 4: "four", 5: "five"}, inplace=True
    )

raw_data
# Out:
#      age  sex     cp  trestbps  chol  fbs restecg  thalach  exang  oldpeak  \
# 0     63    1  three       145   233    1    zero      150      0      2.3
# 1     37    1    two       130   250    0     one      187      0      3.5
# 2     41    0    one       130   204    0    zero      172      0      1.4
# 3     56    1    one       120   236    0     one      178      0      0.8
# 4     57    0   zero       120   354    0     one      163      1      0.6
# ..   ...  ...    ...       ...   ...  ...     ...      ...    ...      ...
# 298   57    0   zero       140   241    0     one      123      1      0.2
# 299   45    1  three       110   264    0     one      132      0      1.2
# 300   68    1   zero       144   193    1     one      141      0      3.4
# 301   57    1   zero       130   131    0     one      115      1      1.2
# 302   57    0    one       130   236    0    zero      174      0      0.0
#
#     slope    ca   thal heart_disease
# ...

# %%
# Check distribution of class column


count_classes = pd.value_counts(raw_data["heart_disease"], sort=True).sort_index()
count_classes.plot(kind="bar", color=["green", "lightblue"])
plt.title("Heart disease")
plt.xlabel("Target")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Now let us check in the number of Percentage
dataframe_class = raw_data["heart_disease"].value_counts().to_frame().reset_index()
dataframe_class["percent"] = dataframe_class["heart_disease"].apply(
    lambda x: round(100 * float(x) / len(raw_data), 2)
)
dataframe_class = dataframe_class.rename(
    columns={"index": "heart_disease", "target": "Count"}
)
dataframe_class
# Out:
#    heart_disease  heart_disease  percent
# 0            Yes            164     54.3
# 1             No            138     45.7

# %% [markdown]
# #### data is pretty balanced

# %%
raw_data.nunique()
# Out:
# age               41
# sex                2
# cp                 4
# trestbps          49
# chol             152
# fbs                2
# restecg            3
# thalach           91
# exang              2
# oldpeak           40
# slope              3
# ca                 5
# thal               4
# heart_disease      2
# dtype: int64

# %%
# print information about dataset
raw_data.describe()
# Out:
#              age         sex    trestbps        chol         fbs     thalach  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119  131.602649  246.500000    0.149007  149.569536
# std      9.04797    0.466426   17.563394   51.753489    0.356686   22.903527
# min     29.00000    0.000000   94.000000  126.000000    0.000000   71.000000
# 25%     48.00000    0.000000  120.000000  211.000000    0.000000  133.250000
# 50%     55.50000    1.000000  130.000000  240.500000    0.000000  152.500000
# 75%     61.00000    1.000000  140.000000  274.750000    0.000000  166.000000
# max     77.00000    1.000000  200.000000  564.000000    1.000000  202.000000
#
#             exang     oldpeak
# count  302.000000  302.000000
# mean     0.327815    1.043046
# std      0.470196    1.161452
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.800000
# 75%      1.000000    1.600000
# ...

# %%
# plot histograms for each variable
raw_data.hist(figsize=(12, 12))
plt.show()

# %%
import visualization

# %%
variable = "sex"
name_of_variable = "sex"
visualization.distribution(raw_data, variable, name_of_variable)

# %%
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# sex
# 0              0.250000  0.750000
# 1              0.553398  0.446602

# %%
variable = "cp"
name_of_variable = "chest pain type "
visualization.distribution(raw_data, variable, name_of_variable)

# %%
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# cp
# one            0.180000  0.820000
# three          0.304348  0.695652
# two            0.209302  0.790698
# zero           0.727273  0.272727

# %%
variable = "fbs"
name_of_variable = "fasting blood sugar > 120 mg/dl"
visualization.distribution(raw_data, variable, name_of_variable)

# %%
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# fbs
# 0              0.451362  0.548638
# 1              0.488889  0.511111

# %%
variable = "restecg"
name_of_variable = "resting electrocardiographic results"
visualization.distribution(raw_data, variable, name_of_variable)

# %%
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# restecg
# one            0.370861  0.629139
# two            0.750000  0.250000
# zero           0.537415  0.462585

# %%
variable = "exang"
name_of_variable = "exercise induced angina"
visualization.distribution(raw_data, variable, name_of_variable)

# %%
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# exang
# 0              0.305419  0.694581
# 1              0.767677  0.232323

# %%
variable = "slope"
name_of_variable = "the slope of the peak exercise ST segment"
visualization.distribution(raw_data, variable, name_of_variable)

# %%
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# slope
# one            0.650000  0.350000
# two            0.248227  0.751773
# zero           0.571429  0.428571

# %%
variable = "ca"
name_of_variable = "number of major vessels (0-3) colored by flourosopy"
visualization.distribution(raw_data, variable, name_of_variable)

# %%
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# ca
# four           0.250000  0.750000
# one            0.676923  0.323077
# three          0.850000  0.150000
# two            0.815789  0.184211
# zero           0.257143  0.742857

# %%
variable = "thal"
name_of_variable = "thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"
visualization.distribution(raw_data, variable, name_of_variable)

# %%
variable = "thal"
name_of_variable = "thalallala"
main_variable = "heart_disease"
visualization.ratio(raw_data, variable, main_variable, name_of_variable)
# Out:
# heart_disease        No       Yes
# thal
# one            0.666667  0.333333
# three          0.760684  0.239316
# two            0.218182  0.781818
# zero           0.500000  0.500000

# %%
(raw_data.thal == "zero").sum()
# Out:
# 2

# %%
def distribution(variable):
    f, ax = plt.subplots(figsize=(10, 6))
    x = raw_data[variable]
    ax = sns.distplot(x, bins=10)
    plt.show()

# %%
def histogram(variable, main_variable):
    plt.figure(figsize=(20, 20))
    plt.subplot(3, 2, 1)
    raw_data[raw_data[main_variable] == "No"][variable].hist(
        bins=35, color="blue", label="Have Heart Disease = NO", alpha=0.6
    )
    raw_data[raw_data[main_variable] == "Yes"][variable].hist(
        bins=35, color="red", label="Have Heart Disease = YES", alpha=0.6
    )
    plt.legend()
    plt.xlabel(variable)

# %%
variable = "age"
distribution(variable)

# %%
variable = "age"
main_variable = "heart_disease"
histogram(variable, main_variable)

# %%
variable = "trestbps"
distribution(variable)

# %%
main_variable = "heart_disease"
histogram(variable, main_variable)

# %%
variable = "chol"
distribution(variable)

# %%
main_variable = "heart_disease"
histogram(variable, main_variable)

# %%
variable = "thalach"
distribution(variable)

# %%
main_variable = "heart_disease"
histogram(variable, main_variable)

# %%
variable = "oldpeak"
distribution(variable)

# %%
main_variable = "heart_disease"
histogram(variable, main_variable)

# %%
raw_data["heart_disease"].replace({"No": 0, "Yes": 1}, inplace=True)

# %%
from sklearn.preprocessing import normalize, LabelEncoder

labelencoder = LabelEncoder()

# %%
change = ["cp", "restecg", "slope", "ca", "thal"]
for c, value in enumerate(change, 1):
    raw_data[value].replace(
        {0: "zero", 1: "one", 2: "two", 3: "three", 4: "four", 5: "five"}, inplace=True
    )
raw_data = pd.get_dummies(raw_data)

# %%
# Split data to X and y
X = raw_data.drop("heart_disease", 1)
y = raw_data.heart_disease

print("Shape of X: {}".format(X.shape))
print("Shape of y: {}".format(y.shape))
# Out:
# Shape of X: (302, 27)
# Shape of y: (302,)

# %%
from sklearn import preprocessing

# raw_data = preprocessing.StandardScaler().fit(raw_data)
X = preprocessing.normalize(X)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
# global variable
SEED = 7
NUM_FOLDS = 10
SCORING = "f1"

# %%
# Compare Algorithms
def compare_algorithms(results, names):
    fig = plt.figure()
    fig.suptitle(" Algorithm Comparison ")
    ax = fig.add_subplot(111)
    plt.boxplot(results)
    ax.set_xticklabels(names)
    plt.show()

# %%
# Algorithms
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

models = []
models.append((" LR ", LogisticRegression()))
models.append((" LDA ", LinearDiscriminantAnalysis()))
models.append((" KNN ", KNeighborsClassifier()))
models.append((" CART ", DecisionTreeClassifier()))
models.append((" NB ", GaussianNB()))
models.append((" AB ", AdaBoostClassifier()))
models.append((" GBM ", GradientBoostingClassifier()))
models.append((" RF ", RandomForestClassifier()))
models.append((" ET ", ExtraTreesClassifier()))
models.append((" SVM ", SVC()))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import timeit

import time


def train_algoritms(model, X_train, y_train, SCORING, NUM_FOLDS, SEED):
    results = []
    names = []
    for name, model in models:
        start = time.time()

        kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED)
        cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=SCORING)
        results.append(cv_results)
        names.append(name)
        end = time.time()
        msg = "%s: %f +/- (%f) Time: %f second" % (
            name,
            cv_results.mean(),
            cv_results.std(),
            end - start,
        )
        print(msg)
    return (results, names)

# %%
# Split data to train sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=SEED
)
print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
print("After OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train == 0)))
# Out:
# Number transactions X_train dataset:  (211, 27)
# Number transactions y_train dataset:  (211,)
# Number transactions X_test dataset:  (91, 27)
# Number transactions y_test dataset:  (91,)
# After OverSampling, counts of label '1': 117
# After OverSampling, counts of label '0': 94

# %%
results, names = train_algoritms(models, X_train, y_train, SCORING, NUM_FOLDS, SEED)
compare_algorithms(results, names)
# Out:
#  LR : 0.708199 +/- (0.103997) Time: 0.077442 second
#  LDA : 0.845257 +/- (0.099377) Time: 0.029735 second
#  KNN : 0.694700 +/- (0.079345) Time: 0.030573 second
#  CART : 0.748452 +/- (0.093187) Time: 0.028343 second
#  NB : 0.789653 +/- (0.095008) Time: 0.019911 second
# /home/spider/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /home/spider/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ...

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
start = time.time()
kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED)
results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=SCORING)
end = time.time()
print(
    "Accuracy: %.2f%% (%.2f%%)  Time: %.2f second"
    % (results.mean() * 100, results.std() * 100, end - start)
)
# Out:
# /home/spider/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Accuracy: 80.16% (8.68%)  Time: 0.54 second

# %%
model = XGBClassifier(tree_method="gpu_hist")
start = time.time()
kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED)
results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=SCORING)
end = time.time()
print(
    "Accuracy: %.2f%% (%.2f%%)   Time: %.2f second"
    % (results.mean() * 100, results.std() * 100, end - start)
)
# Out:
# Accuracy: 81.92% (7.12%)   Time: 1.97 second

# %%
from numpy import loadtxt
from numpy import sort
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

X_train1, X_test1, y_train1, y_test1 = train_test_split(
    X, y, test_size=0.3, random_state=SEED
)
# fit model on all training data
model = XGBClassifier(tree_method="gpu_hist")
model.fit(X_train, y_train)
# make predictions for test data and evaluate
predictions = model.predict(X_test1)
accuracy = accuracy_score(y_test1, predictions)
# print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Fit model using each importance as a threshold
thresholds = sort(model.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection_model = XGBClassifier(tree_method="gpu_hist")
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X)
    # train model
    start = time.time()
    kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED)
    results = cross_val_score(
        selection_model, select_X_train, y, cv=NUM_FOLDS, scoring=SCORING
    )
    end = time.time()
    print(
        "Thresh=%.3f, n=%d, Accuracy: %.2f%% (%.2f%%)   Time: %.2f second"
        % (
            thresh,
            select_X_train.shape[1],
            results.mean() * 100,
            results.std() * 100,
            end - start,
        )
    )

# %load_ext lab_black
# Out:
# /home/spider/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Thresh=0.000, n=27, Accuracy: 83.31% (4.74%)   Time: 2.40 second
# /home/spider/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Thresh=0.000, n=27, Accuracy: 83.31% (4.74%)   Time: 2.41 second
# /home/spider/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
# ...

# %%
from numpy import loadtxt
from numpy import sort
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

X_train1, X_test1, y_train1, y_test1 = train_test_split(
    X, y, test_size=0.3, random_state=SEED
)
# fit model on all training data
model = XGBClassifier(tree_method="gpu_hist")
model.fit(X_train, y_train)
# make predictions for test data and evaluate
predictions = model.predict(X_test1)
accuracy = accuracy_score(y_test1, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Fit model using each importance as a threshold
thresholds = sort(model.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train1)
    # train model
    selection_model = XGBClassifier()
    selection_model.fit(select_X_train, y_train1)
    # eval model
    select_X_test = selection.transform(X_test1)
    predictions = selection_model.predict(select_X_test)
    accuracy = accuracy_score(y_test1, predictions)
    print(
        "Thresh=%.3f, n=%d, Accuracy: %.2f%%"
        % (thresh, select_X_train.shape[1], accuracy * 100.0)
    )
# Out:
# Accuracy: 80.22%
# Thresh=0.000, n=27, Accuracy: 84.62%
# Thresh=0.000, n=27, Accuracy: 84.62%
# Thresh=0.000, n=27, Accuracy: 84.62%
# Thresh=0.000, n=27, Accuracy: 84.62%
# Thresh=0.000, n=27, Accuracy: 84.62%
# Thresh=0.000, n=27, Accuracy: 84.62%
# Thresh=0.000, n=27, Accuracy: 84.62%
# Thresh=0.008, n=20, Accuracy: 84.62%
# Thresh=0.012, n=19, Accuracy: 82.42%
# Thresh=0.020, n=18, Accuracy: 82.42%
# Thresh=0.021, n=17, Accuracy: 80.22%
# Thresh=0.026, n=16, Accuracy: 82.42%
# Thresh=0.027, n=15, Accuracy: 79.12%
# Thresh=0.030, n=14, Accuracy: 81.32%
# Thresh=0.030, n=13, Accuracy: 80.22%
# Thresh=0.034, n=12, Accuracy: 81.32%
# Thresh=0.042, n=11, Accuracy: 81.32%
# Thresh=0.042, n=10, Accuracy: 81.32%
# Thresh=0.047, n=9, Accuracy: 82.42%
# Thresh=0.058, n=8, Accuracy: 86.81%
# Thresh=0.060, n=7, Accuracy: 85.71%
# Thresh=0.063, n=6, Accuracy: 85.71%
# Thresh=0.064, n=5, Accuracy: 83.52%
# Thresh=0.068, n=4, Accuracy: 86.81%
# Thresh=0.073, n=3, Accuracy: 74.73%
# ...

# %% [markdown]
# ### TO DO: select the best model, fine tune model and save parameters
